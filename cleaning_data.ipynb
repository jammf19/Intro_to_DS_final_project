# %%
import pandas as pd

# Read the CSV file with error handling
data = pd.read_csv('halftime_musicians_raw.csv')

# Display the first few rows of the dataframe
print(data.head())
#code to clean/ sort data
# end with data.to_csv('halftime_musicians_cleaned.csv)
# Out:
#   Super_Bowl              Date                       Location           Theme  \
# 0          I  January 15, 1967  Los Angeles Memorial Coliseum               —
# 1         II  January 14, 1968              Miami Orange Bowl               —
# 2        III  January 12, 1969              Miami Orange Bowl  America Thanks
# 3         IV  January 11, 1970    Tulane Stadium, New Orleans      Mardi Gras
# 4    V, show  January 17, 1971              Miami Orange Bowl               —
#
#                                         Performer(s)      Producer  \
# 0  University of Arizona Symphonic Marching Band,...  Tommy Walker
# 1                         Grambling State University             —
# 2  Florida A&M University band, Miami-area high s...             —
# 3  Marguerite Piazza, Doc Severinsen, Al Hirt, Li...             —
# 4  Southeast Missouri State, Anita Bryant, Up Wit...             —
#
#                                              Setlist  \
# 0  " The Sound of Music ", Medley: " Way Down Yon...
# 1                                                  —
# 2                                                  —
# 3  " Do You Know What It Means to Miss New Orlean...
# 4                                                  —
#
#                              Ref. Sponsor Special guest(s) Headliner(s)  \
# 0  [ 10 ], [ 11 ], [ 12 ], [ 13 ]     NaN              NaN          NaN
# 1                             NaN     NaN              NaN          NaN
# 2                          [ 10 ]     NaN              NaN          NaN
# 3                          [ 10 ]       —              NaN          NaN
# 4  [ 10 ], [ 14 ], [ 15 ], [ 16 ]       —              NaN          NaN
#
#   Director
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
#drop columns not used for analysis
data = data.drop(['Location', 'Date', 'Ref.','Sponsor','Producer','Theme','Director'], axis=1)

# %%
#remove duplicate rows
data.drop_duplicates(inplace=True)

# %%
if "Super Bowl" in data.columns:
    data.rename(columns={"Super Bowl": "Super_Bowl"}, inplace=True)

data["Super_Bowl"] = data["Super_Bowl"].str.replace(" show", "", regex=False).str.strip()
data["Super_Bowl"] = data["Super_Bowl"].str.replace("50", "L", regex=False).str.strip()
data["Super_Bowl"] = data["Super_Bowl"].str.replace(",", "", regex=False).str.strip()
print(data.head())
# Out:
#   Super_Bowl                                       Performer(s)  \
# 0          I  University of Arizona Symphonic Marching Band,...
# 1         II                         Grambling State University
# 2        III  Florida A&M University band, Miami-area high s...
# 3         IV  Marguerite Piazza, Doc Severinsen, Al Hirt, Li...
# 4          V  Southeast Missouri State, Anita Bryant, Up Wit...
#
#                                              Setlist Special guest(s)  \
# 0  " The Sound of Music ", Medley: " Way Down Yon...              NaN
# 1                                                  —              NaN
# 2                                                  —              NaN
# 3  " Do You Know What It Means to Miss New Orlean...              NaN
# 4                                                  —              NaN
#
#   Headliner(s)
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
# Define the from_roman_numeral function
def from_roman_numeral(s):
    roman_dict = {'I': 1, 'V': 5, 'X': 10, 'L': 50, 'C': 100, 'D': 500, 'M': 1000}
    total = 0
    prev_value = 0
    
    for char in reversed(s):
        value = roman_dict[char]
        if value < prev_value:
            total -= value
        else:
            total += value
        prev_value = value
    
    return total

# test the function
print(from_roman_numeral('XV'))
# Out:
# 15

# %%
# Apply the function to the Super_Bowl column
data['Super_Bowl'] = data['Super_Bowl'].apply(from_roman_numeral)
print(data.head())
# Out:
#    Super_Bowl                                       Performer(s)  \
# 0           1  University of Arizona Symphonic Marching Band,...
# 1           2                         Grambling State University
# 2           3  Florida A&M University band, Miami-area high s...
# 3           4  Marguerite Piazza, Doc Severinsen, Al Hirt, Li...
# 4           5  Southeast Missouri State, Anita Bryant, Up Wit...
#
#                                              Setlist Special guest(s)  \
# 0  " The Sound of Music ", Medley: " Way Down Yon...              NaN
# 1                                                  —              NaN
# 2                                                  —              NaN
# 3  " Do You Know What It Means to Miss New Orlean...              NaN
# 4                                                  —              NaN
#
#   Headliner(s)
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
missing = data.isnull()
#print missing data
print(missing.sum())
# Out:
# Super_Bowl           0
# Performer(s)        16
# Setlist              0
# Special guest(s)    33
# Headliner(s)        43
# dtype: int64

# %%
# Check for null values in each column separately
bool_series_performers = pd.isnull(data["Performer(s)"])
bool_series_special_guests = pd.isnull(data["Special guest(s)"])
bool_series_headliners = pd.isnull(data["Headliner(s)"])

missing_data_performers = data[bool_series_performers]
missing_data_special_guests = data[bool_series_special_guests]
missing_data_headliners = data[bool_series_headliners]
print(missing_data_performers)
# Out:
#     Super_Bowl Performer(s)  \
# 43          44          NaN
# 44          45          NaN
# 45          46          NaN
# 46          47          NaN
# 47          48          NaN
# 48          49          NaN
# 49          50          NaN
# 50          51          NaN
# 51          52          NaN
# 52          53          NaN
# 53          54          NaN
# 54          55          NaN
# 55          56          NaN
# 56          57          NaN
# 57          58          NaN
# 58          59          NaN
#
#                                               Setlist  \
# 43  " Pinball Wizard ", " Baba O'Riley ", " Who Ar...
# 44  " I Gotta Feeling " (The Black Eyed Peas), " B...
# 45  " Vogue " (Madonna), " Music " / " Party Rock ...
# 46  " Run the World (Girls) " (intro) / Vince Lomb...
# 47  " Billionaire " (intro) (children's choir), " ...
# 48  " Roar " (Katy Perry), " Dark Horse " (Katy Pe...
# 49  " Yellow " (intro a cappella) (Coldplay), " Vi...
# 50  " God Bless America "/" This Land Is Your Land...
# 51  " Filthy ", " Rock Your Body ", " Señorita ", ...
# 52  " Harder to Breathe " (Maroon 5), " This Love ...
# 53  " Dare (La La La) " (Shakira), " She Wolf " (S...
# 54  " Call Out My Name ", " Starboy ", " The Hills...
# 55  " The Next Episode " (Dr. Dre and Snoop Dogg),...
# 56  " What's My Name? " (intro), " Bitch Better Ha...
# 57  " My Way " (intro), " Caught Up " (Usher) (con...
# 58  " Wacced Out Murals " (intro), "Bodies" (Kendr...
#
#                                      Special guest(s)  \
# 43                                                  —
# 44  Usher, Slash, Dallas/Ft. Worth -area area high...
# 45  LMFAO, Cirque du Soleil, Nicki Minaj, M.I.A., ...
# 46                                    Destiny's Child
# 47                              Red Hot Chili Peppers
# 48  Lenny Kravitz, Missy Elliott, Arizona State Un...
# 49  Beyoncé, Bruno Mars, Mark Ronson, Gustavo Duda...
# 50                                                  —
# 51  The Tennessee Kids, University of Minnesota Ma...
# 52  Travis Scott, Big Boi, Georgia State Universit...
# 53                    Bad Bunny, J Balvin, Emme Muñiz
# 54                                                  —
# 55                                     Anderson .Paak
# 56                                                  —
# 57  Alicia Keys, Jermaine Dupri, H.E.R., will.i.am...
# 58   Samuel L. Jackson, SZA, Serena Williams, Mustard
#
#                                          Headliner(s)
# 43                                            The Who
# 44                                The Black Eyed Peas
# 45                                            Madonna
# 46                                            Beyoncé
# 47                                         Bruno Mars
# 48                                         Katy Perry
# 49                                           Coldplay
# 50                                          Lady Gaga
# 51                                  Justin Timberlake
# 52                                           Maroon 5
# 53                            Shakira, Jennifer Lopez
# 54                                         The Weeknd
# 55  Dr. Dre, Snoop Dogg, Eminem, Mary J. Blige, Ke...
# 56                                            Rihanna
# 57                                              Usher
# 58                                     Kendrick Lamar

# %%
print(missing_data_special_guests)
# Out:
#     Super_Bowl                                       Performer(s)  \
# 0            1  University of Arizona Symphonic Marching Band,...
# 1            2                         Grambling State University
# 2            3  Florida A&M University band, Miami-area high s...
# 3            4  Marguerite Piazza, Doc Severinsen, Al Hirt, Li...
# 4            5  Southeast Missouri State, Anita Bryant, Up Wit...
# 5            6  Ella Fitzgerald, Carol Channing, Al Hirt, USAF...
# 6            7  University of Michigan Marching Band, Woody He...
# 7            8  University of Texas Longhorn Band, Judy Mallet...
# 8            9       Mercer Ellington, Grambling State University
# 9           10                                     Up with People
# 10          11                                         card stunt
# 11          12  Tyler Apache Belles Drill Team, The Apache Ban...
# 12          13  Ken Hamilton, Various Caribbean bands, includi...
# 13          14  Up with People, Grambling State University Mar...
# 14          15  Southern University Marching Band, Helen O'Con...
# 15          16                                     Up with People
# 16          17                       Los Angeles Super Drill Team
# 17          18    University of Florida, Florida State University
# 18          19                                       Tops in Blue
# 19          20                                     Up with People
# 20          21  George Burns, Mickey Rooney, Grambling State U...
# 21          22  Chubby Checker, The Rockettes, 88 grand piano ...
# 22          23  Elvis Presto, South Florida -area dancers and ...
# 23          24  Pete Fountain, Doug Kershaw, Irma Thomas, Nich...
# 24          25  New Kids on the Block, Disney characters, Warr...
# 25          26  Gloria Estefan, Olympic figure skaters Brian B...
# 26          27                                    Michael Jackson
# 27          28  Clint Black, Tanya Tucker, Travis Tritt, The J...
# 28          29  Patti LaBelle, Indiana Jones & Marion Ravenwoo...
# 29          30                                         Diana Ross
# 30          31  The Blues Brothers ( Dan Aykroyd , John Goodma...
# 31          32  Boyz II Men, Smokey Robinson, Martha Reeves, T...
# 32          33  Gloria Estefan, Stevie Wonder, Big Bad Voodoo ...
#
#                                               Setlist Special guest(s)  \
# 0   " The Sound of Music ", Medley: " Way Down Yon...              NaN
# 1                                                   —              NaN
# 2                                                   —              NaN
# 3   " Do You Know What It Means to Miss New Orlean...              NaN
# 4                                                   —              NaN
# 5    " Mack the Knife " (Ella Fitzgerald and Al Hirt)              NaN
# 6   " Put on a Happy Face " (University of Michiga...              NaN
# 7                                                   —              NaN
# 8                                                   —              NaN
# 9   " Good Time Neighborhood Band ", " 200 Years a...              NaN
# 10  " It's A Big Wide Wonderful World ", " Paloma ...              NaN
# 11                                                  —              NaN
# 12                                                  —              NaN
# 13  " We Are Many, We Are One ", Big Band Medley: ...              NaN
# 14                                                  —              NaN
# 15  Medley: " The Twist "/" Cool Jerk "/" Monster ...              NaN
# 16  " Look to the Rainbow ", " The Music Goes Roun...              NaN
# 17  Introduction by Phyllis George, " Hooray for H...              NaN
# 18                                                  —              NaN
# 19  " Beat Of The Future ", " Talkin' With My Feet...              NaN
# 20  " Strike Up The Band ", " Ghost Riders in the ...              NaN
# 21  88 Grand Pianos performance, " The Super Bowl ...              NaN
# 22  Introduction by Bob Costas and 3-D commercial ...              NaN
# 23  " (Up A) Lazy River ", " Waiting For The Rober...              NaN
# 24  " It's a Small World After All "/ " We Are the...              NaN
# 25  "Winter Magic", " Walking in a Winter Wonderla...              NaN
# 26  " Jam " (M. Jackson), " Billie Jean " (M. Jack...              NaN
# 27  " Tuckered Out " ( Clint Black ), " It's a Lit...              NaN
# 28  " Release Yourself " (Patti LaBelle), " Carava...              NaN
# 29  " Stop In The Name Of Love ", " You Keep Me Ha...              NaN
# 30  " Everybody Needs Somebody to Love " (The Blue...              NaN
# 31  " Get Ready " (The Temptations), " I Can't Hel...              NaN
# 32  "Go Daddy O" (Big Bad Voodoo Daddy), " Sir Duk...              NaN
#
#    Headliner(s)
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
# 30          NaN
# 31          NaN
# 32          NaN

# %%
print(missing_data_headliners)
# Out:
#     Super_Bowl                                       Performer(s)  \
# 0            1  University of Arizona Symphonic Marching Band,...
# 1            2                         Grambling State University
# 2            3  Florida A&M University band, Miami-area high s...
# 3            4  Marguerite Piazza, Doc Severinsen, Al Hirt, Li...
# 4            5  Southeast Missouri State, Anita Bryant, Up Wit...
# 5            6  Ella Fitzgerald, Carol Channing, Al Hirt, USAF...
# 6            7  University of Michigan Marching Band, Woody He...
# 7            8  University of Texas Longhorn Band, Judy Mallet...
# 8            9       Mercer Ellington, Grambling State University
# 9           10                                     Up with People
# 10          11                                         card stunt
# 11          12  Tyler Apache Belles Drill Team, The Apache Ban...
# 12          13  Ken Hamilton, Various Caribbean bands, includi...
# 13          14  Up with People, Grambling State University Mar...
# 14          15  Southern University Marching Band, Helen O'Con...
# 15          16                                     Up with People
# 16          17                       Los Angeles Super Drill Team
# 17          18    University of Florida, Florida State University
# 18          19                                       Tops in Blue
# 19          20                                     Up with People
# 20          21  George Burns, Mickey Rooney, Grambling State U...
# 21          22  Chubby Checker, The Rockettes, 88 grand piano ...
# 22          23  Elvis Presto, South Florida -area dancers and ...
# 23          24  Pete Fountain, Doug Kershaw, Irma Thomas, Nich...
# 24          25  New Kids on the Block, Disney characters, Warr...
# 25          26  Gloria Estefan, Olympic figure skaters Brian B...
# 26          27                                    Michael Jackson
# 27          28  Clint Black, Tanya Tucker, Travis Tritt, The J...
# 28          29  Patti LaBelle, Indiana Jones & Marion Ravenwoo...
# 29          30                                         Diana Ross
# 30          31  The Blues Brothers ( Dan Aykroyd , John Goodma...
# 31          32  Boyz II Men, Smokey Robinson, Martha Reeves, T...
# 32          33  Gloria Estefan, Stevie Wonder, Big Bad Voodoo ...
# 33          34  Phil Collins, Christina Aguilera, Enrique Igle...
# 34          35                                   Aerosmith, NSYNC
# 35          36                                                 U2
# 36          37                             Shania Twain, No Doubt
# 37          38  Janet Jackson, P. Diddy, Nelly, Kid Rock, Just...
# 38          39                                     Paul McCartney
# 39          40                                 The Rolling Stones
# 40          41                                             Prince
# 41          42                    Tom Petty and the Heartbreakers
# 42          43                   Bruce Springsteen, E Street Band
#
#                                               Setlist  \
# 0   " The Sound of Music ", Medley: " Way Down Yon...
# 1                                                   —
# 2                                                   —
# 3   " Do You Know What It Means to Miss New Orlean...
# 4                                                   —
# 5    " Mack the Knife " (Ella Fitzgerald and Al Hirt)
# 6   " Put on a Happy Face " (University of Michiga...
# 7                                                   —
# 8                                                   —
# 9   " Good Time Neighborhood Band ", " 200 Years a...
# 10  " It's A Big Wide Wonderful World ", " Paloma ...
# 11                                                  —
# 12                                                  —
# 13  " We Are Many, We Are One ", Big Band Medley: ...
# 14                                                  —
# 15  Medley: " The Twist "/" Cool Jerk "/" Monster ...
# 16  " Look to the Rainbow ", " The Music Goes Roun...
# 17  Introduction by Phyllis George, " Hooray for H...
# 18                                                  —
# 19  " Beat Of The Future ", " Talkin' With My Feet...
# 20  " Strike Up The Band ", " Ghost Riders in the ...
# 21  88 Grand Pianos performance, " The Super Bowl ...
# 22  Introduction by Bob Costas and 3-D commercial ...
# 23  " (Up A) Lazy River ", " Waiting For The Rober...
# 24  " It's a Small World After All "/ " We Are the...
# 25  "Winter Magic", " Walking in a Winter Wonderla...
# 26  " Jam " (M. Jackson), " Billie Jean " (M. Jack...
# 27  " Tuckered Out " ( Clint Black ), " It's a Lit...
# 28  " Release Yourself " (Patti LaBelle), " Carava...
# 29  " Stop In The Name Of Love ", " You Keep Me Ha...
# 30  " Everybody Needs Somebody to Love " (The Blue...
# 31  " Get Ready " (The Temptations), " I Can't Hel...
# 32  "Go Daddy O" (Big Bad Voodoo Daddy), " Sir Duk...
# 33  " Reflections of Earth " Instrumental ( Walt D...
# 34  Pre-recorded intro sketch with Ben Stiller , A...
# 35  " Beautiful Day ", " MLK ", " Where the Street...
# 36  " Man! I Feel like a Woman! " (Shania Twain), ...
# 37  " The Way You Move " (Spirit of Houston and Oc...
# 38  " Drive My Car ", " Get Back ", " Live and Let...
# 39  " Start Me Up ", " Rough Justice ", " (I Can't...
# 40  " We Will Rock You " (Intro), " Let's Go Crazy...
# 41  " American Girl ", " I Won't Back Down ", " Fr...
# 42  " Tenth Avenue Freeze-Out ", " Born to Run ", ...
#
#                             Special guest(s) Headliner(s)
# 0                                        NaN          NaN
# 1                                        NaN          NaN
# 2                                        NaN          NaN
# 3                                        NaN          NaN
# 4                                        NaN          NaN
# 5                                        NaN          NaN
# 6                                        NaN          NaN
# 7                                        NaN          NaN
# 8                                        NaN          NaN
# 9                                        NaN          NaN
# 10                                       NaN          NaN
# 11                                       NaN          NaN
# 12                                       NaN          NaN
# 13                                       NaN          NaN
# 14                                       NaN          NaN
# 15                                       NaN          NaN
# 16                                       NaN          NaN
# 17                                       NaN          NaN
# 18                                       NaN          NaN
# 19                                       NaN          NaN
# 20                                       NaN          NaN
# 21                                       NaN          NaN
# 22                                       NaN          NaN
# 23                                       NaN          NaN
# 24                                       NaN          NaN
# 25                                       NaN          NaN
# 26                                       NaN          NaN
# 27                                       NaN          NaN
# 28                                       NaN          NaN
# 29                                       NaN          NaN
# 30                                       NaN          NaN
# 31                                       NaN          NaN
# 32                                       NaN          NaN
# 33                                         —          NaN
# 34      Britney Spears, Mary J. Blige, Nelly          NaN
# 35                                         —          NaN
# 36                                     Sting          NaN
# 37          Spirit of Houston, Ocean of Soul          NaN
# 38                                         —          NaN
# 39                                         —          NaN
# 40  Florida A&M University Marching 100 Band          NaN
# 41                                         —          NaN
# 42                           The Miami Horns          NaN

# %% [markdown]
# Upon initial ispection we can see that 3 columns have missing values and after taking a closer look at the columns superbowls 1-42 have missing data in performers column and superbowls 44 - 59 have missing data in headliner(s) column.
# As for the missing data in special guest(s), i understand that not every halftime performance included a special guest
# As all columns are relevant for for analysis because we are looking at performers/musicians i will create a column merging all three.

# %%
# Fill NaN values with an empty string
data['Headliner(s)'] = data['Headliner(s)'].fillna('')
data['Special guest(s)'] = data['Special guest(s)'].fillna('')
data['Performer(s)'] = data['Performer(s)'].fillna('')

# Concatenate the columns into a new column while ignoring NaN values
data['Musician'] = data[['Headliner(s)','Special guest(s)', 'Performer(s)']].fillna('').agg(', '.join, axis=1).str.strip(', ')

# Remove leading and trailing commas and spaces
data['Musician'] = data['Musician'].str.strip(', ')
display(data.head())
# Out:
#    Super_Bowl                                       Performer(s)  \
# 0           1  University of Arizona Symphonic Marching Band,...
# 1           2                         Grambling State University
# 2           3  Florida A&M University band, Miami-area high s...
# 3           4  Marguerite Piazza, Doc Severinsen, Al Hirt, Li...
# 4           5  Southeast Missouri State, Anita Bryant, Up Wit...
#
#                                              Setlist Special guest(s)  \
# 0  " The Sound of Music ", Medley: " Way Down Yon...
# 1                                                  —
# 2                                                  —
# 3  " Do You Know What It Means to Miss New Orlean...
# 4                                                  —
#
#   Headliner(s)                                           Musician
# 0               University of Arizona Symphonic Marching Band,...
# 1                                      Grambling State University
# 2               Florida A&M University band, Miami-area high s...
# 3               Marguerite Piazza, Doc Severinsen, Al Hirt, Li...
# 4               Southeast Missouri State, Anita Bryant, Up Wit...

# %%
# Split the 'Musician' column into multiple rows
data_split = data.set_index(['Super_Bowl','Setlist','Headliner(s)','Performer(s)']).Musician.str.split(',', expand=True).stack().reset_index(level=4, drop=True).reset_index(name='Musician(s)')
print(data_split.head())
display(data_split.head())
# Out:
#    Super_Bowl                                            Setlist Headliner(s)  \
# 0           1  " The Sound of Music ", Medley: " Way Down Yon...
# 1           1  " The Sound of Music ", Medley: " Way Down Yon...
# 2           1  " The Sound of Music ", Medley: " Way Down Yon...
# 3           1  " The Sound of Music ", Medley: " Way Down Yon...
# 4           2                                                  —
#
#                                         Performer(s)  \
# 0  University of Arizona Symphonic Marching Band,...
# 1  University of Arizona Symphonic Marching Band,...
# 2  University of Arizona Symphonic Marching Band,...
# 3  University of Arizona Symphonic Marching Band,...
# 4                         Grambling State University
#
#                                          Musician(s)
# 0      University of Arizona Symphonic Marching Band
# 1           Grambling State University Marching Band
# 2                                            Al Hirt
# 3   Anaheim High School Ana-Hi-Steppers Drill Tea...
# 4                         Grambling State University
#    Super_Bowl                                            Setlist Headliner(s)  \
# 0           1  " The Sound of Music ", Medley: " Way Down Yon...
# 1           1  " The Sound of Music ", Medley: " Way Down Yon...
# 2           1  " The Sound of Music ", Medley: " Way Down Yon...
# 3           1  " The Sound of Music ", Medley: " Way Down Yon...
# 4           2                                                  —
#
#                                         Performer(s)  \
# 0  University of Arizona Symphonic Marching Band,...
# 1  University of Arizona Symphonic Marching Band,...
# 2  University of Arizona Symphonic Marching Band,...
# 3  University of Arizona Symphonic Marching Band,...
# 4                         Grambling State University
#
#                                          Musician(s)
# 0      University of Arizona Symphonic Marching Band
# 1           Grambling State University Marching Band
# 2                                            Al Hirt
# 3   Anaheim High School Ana-Hi-Steppers Drill Tea...
# 4                         Grambling State University

# %%
# Verify the datatypes of the 'Setlist' and 'Musician(s)' columns
print(data_split['Setlist'].dtype)
print(data_split['Musician(s)'].dtype)
# Out:
# object
# object

# %%
# Define a function to count the number of times each musician is mentioned in the Setlist
def count_musician_mentions(row):
    musician = row['Musician(s)'].strip()
    setlist = row['Setlist'].strip()
    return setlist.count(musician)

# Apply the function to each row and create a new column 'num_songs'
data_split['num_songs'] = data_split.apply(count_musician_mentions, axis=1)

# View the updated DataFrame
display(data_split.tail())
# Out:
#      Super_Bowl                                            Setlist  \
# 206          59  " Wacced Out Murals " (intro), "Bodies" (Kendr...
# 207          59  " Wacced Out Murals " (intro), "Bodies" (Kendr...
# 208          59  " Wacced Out Murals " (intro), "Bodies" (Kendr...
# 209          59  " Wacced Out Murals " (intro), "Bodies" (Kendr...
# 210          59  " Wacced Out Murals " (intro), "Bodies" (Kendr...
#
#        Headliner(s) Performer(s)         Musician(s)  num_songs
# 206  Kendrick Lamar                   Kendrick Lamar         11
# 207  Kendrick Lamar                Samuel L. Jackson          0
# 208  Kendrick Lamar                              SZA          2
# 209  Kendrick Lamar                  Serena Williams          0
# 210  Kendrick Lamar                          Mustard          0

# %%
#if in the same row headliner and musician(s) are the same  then num_songs = number of songs in setlist
# if in the same row headliner and musician(s) are different then num_songs = 0
def update_num_songs(df):
    # Define a helper function to count the number of songs in the setlist
    def count_songs(setlist):
        if pd.isna(setlist):
            return 0
        return len(setlist.split(','))
    
    #Strip whitespaces from the columns
    df['Headliner(s)'] = df['Headliner(s)'].str.strip()
    df['Musician(s)'] = df['Musician(s)'].str.strip()
    


    # Update the num_songs column for when headliners and musicians are the same
    def update_num_songs_row(row):
        if row['Musician(s)'] in row['Headliner(s)']:
            if len(row['Headliner(s)'].split(',')) == 1:
                return count_songs(row['Setlist'])
        elif row['num_songs'] == 0 and row['Musician(s)'] in row['Performer(s)']:
            return count_songs(row['Setlist'])
        return row['num_songs']

    df['num_songs'] = df.apply(update_num_songs_row, axis=1)

    return df

df2 = update_num_songs(data_split)

display(df2.tail())
# Out:
#      Super_Bowl                                            Setlist  \
# 206          59  " Wacced Out Murals " (intro), "Bodies" (Kendr...
# 207          59  " Wacced Out Murals " (intro), "Bodies" (Kendr...
# 208          59  " Wacced Out Murals " (intro), "Bodies" (Kendr...
# 209          59  " Wacced Out Murals " (intro), "Bodies" (Kendr...
# 210          59  " Wacced Out Murals " (intro), "Bodies" (Kendr...
#
#        Headliner(s) Performer(s)        Musician(s)  num_songs
# 206  Kendrick Lamar                  Kendrick Lamar         12
# 207  Kendrick Lamar               Samuel L. Jackson          0
# 208  Kendrick Lamar                             SZA          2
# 209  Kendrick Lamar                 Serena Williams          0
# 210  Kendrick Lamar                         Mustard          0

# %%
# Save data before non-musicians are removed
df2.to_csv('halftime_musicians_initial_clean.csv')

# %%
#print rows where num_songs == 0
no_songs = df2[df2['num_songs'] == 0]
print(no_songs)
# Out:
#      Super_Bowl                                            Setlist  \
# 102          34  " Reflections of Earth " Instrumental ( Walt D...
# 114          36  " Beautiful Day ", " MLK ", " Where the Street...
# 127          39  " Drive My Car ", " Get Back ", " Live and Let...
# 129          40  " Start Me Up ", " Rough Justice ", " (I Can't...
# 131          41  " We Will Rock You " (Intro), " Let's Go Crazy...
# 133          42  " American Girl ", " I Won't Back Down ", " Fr...
# 135          43  " Tenth Avenue Freeze-Out ", " Born to Run ", ...
# 139          44  " Pinball Wizard ", " Baba O'Riley ", " Who Ar...
# 143          45  " I Gotta Feeling " (The Black Eyed Peas), " B...
# 144          45  " I Gotta Feeling " (The Black Eyed Peas), " B...
# 147          46  " Vogue " (Madonna), " Music " / " Party Rock ...
# 151          46  " Vogue " (Madonna), " Music " / " Party Rock ...
# 152          46  " Vogue " (Madonna), " Music " / " Party Rock ...
# 153          46  " Vogue " (Madonna), " Music " / " Party Rock ...
# 154          46  " Vogue " (Madonna), " Music " / " Party Rock ...
# 155          46  " Vogue " (Madonna), " Music " / " Party Rock ...
# 156          46  " Vogue " (Madonna), " Music " / " Party Rock ...
# 157          46  " Vogue " (Madonna), " Music " / " Party Rock ...
# 165          49  " Roar " (Katy Perry), " Dark Horse " (Katy Pe...
# 170          50  " Yellow " (intro a cappella) (Coldplay), " Vi...
# 171          50  " Yellow " (intro a cappella) (Coldplay), " Vi...
# 172          50  " Yellow " (intro a cappella) (Coldplay), " Vi...
# 174          51  " God Bless America "/" This Land Is Your Land...
# 176          52  " Filthy ", " Rock Your Body ", " Señorita ", ...
# 181          53  " Harder to Breathe " (Maroon 5), " This Love ...
# 188          55  " Call Out My Name ", " Starboy ", " The Hills...
# 197          57  " What's My Name? " (intro), " Bitch Better Ha...
# 205          58  " My Way " (intro), " Caught Up " (Usher) (con...
# 207          59  " Wacced Out Murals " (intro), "Bodies" (Kendr...
# 209          59  " Wacced Out Murals " (intro), "Bodies" (Kendr...
# 210          59  " Wacced Out Murals " (intro), "Bodies" (Kendr...
#
#             Headliner(s)                                       Performer(s)  \
# 102                       Phil Collins, Christina Aguilera, Enrique Igle...
# 114                                                                      U2
# 127                                                          Paul McCartney
# 129                                                      The Rolling Stones
# 131                                                                  Prince
# 133                                         Tom Petty and the Heartbreakers
# 135                                        Bruce Springsteen, E Street Band
# 139              The Who
# 143  The Black Eyed Peas
# 144  The Black Eyed Peas
# 147              Madonna
# 151              Madonna
# 152              Madonna
# 153              Madonna
# 154              Madonna
# 155              Madonna
# 156              Madonna
# 157              Madonna
# 165           Katy Perry
# 170             Coldplay
# 171             Coldplay
# 172             Coldplay
# 174            Lady Gaga
# 176    Justin Timberlake
# 181             Maroon 5
# 188           The Weeknd
# 197              Rihanna
# 205                Usher
# 207       Kendrick Lamar
# 209       Kendrick Lamar
# 210       Kendrick Lamar
#
#                                            Musician(s)  num_songs
# 102                                                  —          0
# 114                                                  —          0
# 127                                                  —          0
# 129                                                  —          0
# 131           Florida A&M University Marching 100 Band          0
# 133                                                  —          0
# 135                                    The Miami Horns          0
# 139                                                  —          0
# 143  Dallas/Ft. Worth -area area high school drill ...          0
# 144         Prairie View A&M University Marching Storm          0
# 147                                   Cirque du Soleil          0
# 151                                         Andy Lewis          0
# 152                          Avon High School Drumline          0
# 153                  Center Grove High School Drumline          0
# 154                       Fishers High School Drumline          0
# 155              Franklin Central High School Drumline          0
# 156                  Southern University Dancing Dolls          0
# 157  200-person choir consisting of Indianapolis lo...          0
# 165   Arizona State University Sun Devil Marching Band          0
# 170                                    Gustavo Dudamel          0
# 171             University of California Marching Band          0
# 172                        Youth Orchestra Los Angeles          0
# 174                                                  —          0
# 176                                 The Tennessee Kids          0
# 181             Georgia State University Marching Band          0
# 188                                                  —          0
# 197                                                  —          0
# 205                            Sonic Boom of the South          0
# 207                                  Samuel L. Jackson          0
# 209                                    Serena Williams          0
# 210                                            Mustard          0

# %%
#save data of non-musicians that will be removed soon
no_songs_df = pd.DataFrame(no_songs)
no_songs_df.to_csv('no_songs.csv')

# %%
#filter out non-musicians
musicians = df2[df2['num_songs'] > 0]
print(musicians)
# Out:
#      Super_Bowl                                            Setlist  \
# 0             1  " The Sound of Music ", Medley: " Way Down Yon...
# 1             1  " The Sound of Music ", Medley: " Way Down Yon...
# 2             1  " The Sound of Music ", Medley: " Way Down Yon...
# 3             1  " The Sound of Music ", Medley: " Way Down Yon...
# 4             2                                                  —
# ..          ...                                                ...
# 202          58  " My Way " (intro), " Caught Up " (Usher) (con...
# 203          58  " My Way " (intro), " Caught Up " (Usher) (con...
# 204          58  " My Way " (intro), " Caught Up " (Usher) (con...
# 206          59  " Wacced Out Murals " (intro), "Bodies" (Kendr...
# 208          59  " Wacced Out Murals " (intro), "Bodies" (Kendr...
#
#        Headliner(s)                                       Performer(s)  \
# 0                    University of Arizona Symphonic Marching Band,...
# 1                    University of Arizona Symphonic Marching Band,...
# 2                    University of Arizona Symphonic Marching Band,...
# 3                    University of Arizona Symphonic Marching Band,...
# 4                                           Grambling State University
# ..              ...                                                ...
# 202           Usher
# 203           Usher
# 204           Usher
# 206  Kendrick Lamar
# 208  Kendrick Lamar
#
#                                            Musician(s)  num_songs
# 0        University of Arizona Symphonic Marching Band          8
# 1             Grambling State University Marching Band          8
# 2                                              Al Hirt          2
# 3    Anaheim High School Ana-Hi-Steppers Drill Team...          8
# 4                           Grambling State University          1
# ..                                                 ...        ...
# 202                                          will.i.am          1
# 203                                            Lil Jon          2
# 204                                           Ludacris          1
# 206                                     Kendrick Lamar         12
# 208                                                SZA          2
#
# [180 rows x 6 columns]

# %%
#212-32 = 180 musicians
musicians = musicians.drop(['Setlist','Performer(s)','Headliner(s)'],axis=1)

# %%
musicians = musicians.sort_values(by='Super_Bowl', ascending=False)
#remane musician(s) to musician
musicians.rename(columns={'Musician(s)': 'Musician'}, inplace=True)

# %%
print(musicians.head())

musicians.to_csv('halftime_musicians_cleaned.csv', index=False)
print('halftime_musicians_cleaned.csv')
# Out:
#      Super_Bowl        Musician  num_songs
# 208          59             SZA          2
# 206          59  Kendrick Lamar         12
# 198          58           Usher         13
# 204          58        Ludacris          1
# 201          58          H.E.R.          1
# halftime_musicians_cleaned.csv
